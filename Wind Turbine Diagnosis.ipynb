# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('Data-Wind_turbine_diagnosis.xlsx', sheet_name='Data', index_col='DateTime')

# %%
data.shape
# Out:
# (30683, 21)

# %%
data.head()
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-05-07 12:10:00         0.000   10.304991                0.029475
# 2015-05-07 13:10:00         0.000   12.114834                0.039450
# 2015-05-07 13:30:00         0.000   11.625033                0.049417
# 2015-05-07 13:40:00         0.000   10.197867                0.040475
# 2015-05-07 13:50:00         1.645   10.796599                0.020867
#
#                       Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# DateTime
# 2015-05-07 12:10:00    0.000000   0.000000     28.100000         33.074312
# 2015-05-07 13:10:00    2.561702   0.008035     27.790823         32.318149
# 2015-05-07 13:30:00    4.439519   2.413139     27.613112         32.154716
# 2015-05-07 13:40:00   13.661278   3.918215     27.479778         32.073000
# 2015-05-07 13:50:00  172.699256   5.816421     27.346445         32.650275
#
# ...

# %%
data.tail()
# Out:
#                  DateTime  Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# 30678 2015-12-31 23:10:00    316.585833    5.658485                0.020000
# 30679 2015-12-31 23:20:00    295.466389    5.575885                0.020000
# 30680 2015-12-31 23:30:00    272.371111    5.419472                0.038900
# 30681 2015-12-31 23:40:00    327.105167    5.631479                0.040000
# 30682 2015-12-31 23:50:00    399.202056    5.921950                0.030458
#
#         Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# 30678  790.354213  12.008152     -4.719852         36.478393
# 30679  786.630403  11.993648     -4.741828         36.271892
# 30680  781.740247  11.979145     -4.763804         36.065391
# 30681  792.530910  11.964641     -4.785780         35.858890
# 30682  804.566172  11.950137     -4.807756         35.652389
#
#        Hydraulic.Oil.Temp  Nacelle.Temp         ...          \
# 30678           16.816799      8.412677         ...
# ...

# %%
data.isnull().sum()
# Out:
# DateTime                  0
# Active.Power              0
# Wind.Speed                0
# Tower.Acceleration.RMS    0
# Gen.Speed                 0
# Hub.Speed                 0
# Ambient.Temp              0
# Gearbox.Oil.Temp          0
# Hydraulic.Oil.Temp        0
# Nacelle.Temp              0
# PCU.Heatsink.Temp         0
# PCU.Blade1.Motor.Temp     0
# PCU.Blade2.Motor.Temp     0
# PCU.Blade3.Motor.Temp     0
# Timer.Yaw                 0
# Direction_x               0
# Yaw.Error                 0
# Air.Density               0
# Blade.Rotor.Angle         0
# Blade1.Pitch.Angle        0
# Blade2.Pitch.Angle        0
# Blade3.Pitch.Angle        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30683 entries, 0 to 30682
# Data columns (total 22 columns):
# DateTime                  30683 non-null datetime64[ns]
# Active.Power              30683 non-null float64
# Wind.Speed                30683 non-null float64
# Tower.Acceleration.RMS    30683 non-null float64
# Gen.Speed                 30683 non-null float64
# Hub.Speed                 30683 non-null float64
# Ambient.Temp              30683 non-null float64
# Gearbox.Oil.Temp          30683 non-null float64
# Hydraulic.Oil.Temp        30683 non-null float64
# Nacelle.Temp              30683 non-null float64
# PCU.Heatsink.Temp         30683 non-null float64
# PCU.Blade1.Motor.Temp     30683 non-null float64
# PCU.Blade2.Motor.Temp     30683 non-null float64
# PCU.Blade3.Motor.Temp     30683 non-null float64
# Timer.Yaw                 30683 non-null float64
# Direction_x               30683 non-null float64
# Yaw.Error                 30683 non-null float64
# ...

# %%
data.describe()
# Out:
#        Active.Power    Wind.Speed  Tower.Acceleration.RMS     Gen.Speed  \
# count  30683.000000  30683.000000            30683.000000  30683.000000
# mean     728.566346      6.633183               -0.276776    813.482058
# std      739.956127     57.198866               57.083401    293.503063
# min    -9999.000000  -9999.000000            -9999.000000  -9999.000000
# 25%      140.533285      4.765845                0.030500    757.195729
# 50%      476.985874      6.635502                0.048917    827.307082
# 75%     1104.149834      8.697716                0.069679   1012.204725
# max     2591.780833     21.897778                0.188050   1137.727662
#
#           Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  Hydraulic.Oil.Temp  \
# count  30683.000000  30683.000000      30683.000000        30683.000000
# mean      10.667141     15.438503         39.811843           33.754864
# std       57.269949     57.761426         57.562619           57.947604
# ...

# %%
data[data['Tower.Acceleration.RMS']<0]
# Out:
#                  DateTime  Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# 30246 2015-12-28 12:20:00       -9999.0     -9999.0                 -9999.0
#
#        Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# 30246    -9999.0    -9999.0       -9999.0           -9999.0
#
#        Hydraulic.Oil.Temp  Nacelle.Temp         ...          \
# 30246             -9999.0       -9999.0         ...
#
#        PCU.Blade2.Motor.Temp  PCU.Blade3.Motor.Temp  Timer.Yaw  Direction_x  \
# 30246                -9999.0                -9999.0    -9999.0        3.791
#
#        Yaw.Error  Air.Density  Blade.Rotor.Angle  Blade1.Pitch.Angle  \
# 30246    -9999.0      -9999.0            -9999.0             -9999.0
#
#        Blade2.Pitch.Angle  Blade3.Pitch.Angle
# 30246             -9999.0             -9999.0
#
# [1 rows x 22 columns]

# %%
data[data['Active.Power'] == -9999]
# Out:
#                  DateTime  Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# 30246 2015-12-28 12:20:00       -9999.0     -9999.0                 -9999.0
#
#        Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# 30246    -9999.0    -9999.0       -9999.0           -9999.0
#
#        Hydraulic.Oil.Temp  Nacelle.Temp         ...          \
# 30246             -9999.0       -9999.0         ...
#
#        PCU.Blade2.Motor.Temp  PCU.Blade3.Motor.Temp  Timer.Yaw  Direction_x  \
# 30246                -9999.0                -9999.0    -9999.0        3.791
#
#        Yaw.Error  Air.Density  Blade.Rotor.Angle  Blade1.Pitch.Angle  \
# 30246    -9999.0      -9999.0            -9999.0             -9999.0
#
#        Blade2.Pitch.Angle  Blade3.Pitch.Angle
# 30246             -9999.0             -9999.0
#
# [1 rows x 22 columns]

# %%
data[data['Wind.Speed'] == -9999].index
# Out:
# DatetimeIndex(['2015-12-28 12:20:00'], dtype='datetime64[ns]', name='DateTime', freq=None)

# %%
data.drop(pd.Timestamp('2015-12-28 12:20:00'), inplace=True)

# %%
data[data['Wind.Speed'] == -9999]
# Out:
# Empty DataFrame
# Columns: [Active.Power, Wind.Speed, Tower.Acceleration.RMS, Gen.Speed, Hub.Speed, Ambient.Temp, Gearbox.Oil.Temp, Hydraulic.Oil.Temp, Nacelle.Temp, PCU.Heatsink.Temp, PCU.Blade1.Motor.Temp, PCU.Blade2.Motor.Temp, PCU.Blade3.Motor.Temp, Timer.Yaw, Direction_x, Yaw.Error, Air.Density, Blade.Rotor.Angle, Blade1.Pitch.Angle, Blade2.Pitch.Angle, Blade3.Pitch.Angle]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.corr()
# Out:
#                         Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# Active.Power                1.000000    0.130751                0.083116
# Wind.Speed                  0.130751    1.000000                0.998689
# Tower.Acceleration.RMS      0.083116    0.998689                1.000000
# Gen.Speed                   0.729246    0.246713                0.210660
# Hub.Speed                   0.129765    0.998971                0.997856
# Ambient.Temp                0.037727    0.986532                0.989798
# Gearbox.Oil.Temp            0.145236    0.997606                0.995676
# Hydraulic.Oil.Temp          0.067172    0.986621                0.988440
# Nacelle.Temp                0.083949    0.991145                0.992201
# PCU.Heatsink.Temp           0.067880    0.995744                0.997670
# PCU.Blade1.Motor.Temp       0.082215    0.997753                0.999097
# PCU.Blade2.Motor.Temp       0.060142    0.993126                0.995347
# ...

# %%
#After removing -9999  row, corr

# %%
data.corr()
# Out:
#                         Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# Active.Power                1.000000    0.936339                0.737319
# Wind.Speed                  0.936339    1.000000                0.732435
# Tower.Acceleration.RMS      0.737319    0.732435                1.000000
# Gen.Speed                   0.730631    0.727830                0.735368
# Hub.Speed                   0.719558    0.726501                0.736813
# Ambient.Temp               -0.311530   -0.268124               -0.240102
# Gearbox.Oil.Temp            0.676699    0.682882                0.568860
# Hydraulic.Oil.Temp         -0.096883   -0.064536                0.012520
# Nacelle.Temp                0.014705    0.041609                0.075616
# PCU.Heatsink.Temp          -0.216302   -0.171731               -0.096648
# PCU.Blade1.Motor.Temp      -0.011308   -0.007890               -0.058245
# PCU.Blade2.Motor.Temp      -0.231713   -0.181694               -0.081598
# ...

# %%
data.describe()
# Out:
#        Active.Power    Wind.Speed  Tower.Acceleration.RMS     Gen.Speed  \
# count  30682.000000  30682.000000            30682.000000  30682.000000
# mean     728.915984      6.959291                0.049106    813.834463
# std      737.429262      2.948088                0.027098    286.942917
# min       -0.058837      0.000000                0.000000    -35.110603
# 25%      140.558289      4.766054                0.030500    757.201525
# 50%      476.986615      6.635628                0.048921    827.317381
# 75%     1104.151000      8.697956                0.069681   1012.206740
# max     2591.780833     21.897778                0.188050   1137.727662
#
#           Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  Hydraulic.Oil.Temp  \
# count  30682.000000  30682.000000      30682.000000        30682.000000
# mean      10.993380     15.764897         40.139032           34.081855
# std        3.767831      8.223110          5.362890            8.786025
# ...

# %%
iqr = np.quantile(data['Active.Power'], 0.75) - np.quantile(data['Active.Power'], 0.25)
iqr
# Out:
# 963.592711575

# %%
upper_limit = np.quantile(data['Active.Power'], 0.75) + 1.5 * iqr
upper_limit
# Out:
# 2549.5400676125

# %%
data[data['Active.Power']> upper_limit]
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-05-10 22:20:00   2552.731120   13.252987                0.090000
# 2015-05-10 22:30:00   2565.138426   12.603908                0.070733
# 2015-05-25 01:00:00   2554.798333   12.783306                0.080000
# 2015-05-25 04:50:00   2575.833333   14.427347                0.099542
# 2015-05-25 05:10:00   2554.041667   13.041087                0.110000
# 2015-05-25 06:10:00   2572.831667   14.059139                0.108917
# 2015-05-25 06:20:00   2556.978333   13.730410                0.100542
# 2015-05-25 07:30:00   2567.399167   12.986208                0.099083
# 2015-05-25 08:40:00   2574.340833   14.104375                0.090542
# 2015-05-25 09:00:00   2566.063333   13.961208                0.100000
# 2015-05-25 09:30:00   2571.259167   14.239375                0.100000
# 2015-05-25 09:40:00   2570.718333   14.031125                0.109542
# ...

# %%
1.5*iqr
# Out:
# 1445.3890673624999

# %%
plt.plot(data['Active.Power'])

# %%
data[data['Wind.Speed'] == 0]
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-06-08 12:50:00           0.0         0.0                     0.0
# 2015-06-08 13:00:00           0.0         0.0                     0.0
#
#                      Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# DateTime
# 2015-06-08 12:50:00        0.0   0.054516     23.489457         47.305841
# 2015-06-08 13:00:00        0.0   0.000194     23.635710         47.478876
#
#                      Hydraulic.Oil.Temp  Nacelle.Temp  PCU.Heatsink.Temp  \
# DateTime
# 2015-06-08 12:50:00           36.063341     29.968336                0.0
# 2015-06-08 13:00:00           36.131970     29.710582                0.0
#
#                             ...          PCU.Blade2.Motor.Temp  \
# DateTime                    ...
# 2015-06-08 12:50:00         ...                            0.0
# 2015-06-08 13:00:00         ...                            0.0
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(data['Active.Power'])

# %%
import seaborn as sns

# %%
plt.figure(figsize = (200,8))

# %%
data.iloc[0:100,]
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-05-07 12:10:00      0.000000   10.304991                0.029475
# 2015-05-07 13:10:00      0.000000   12.114834                0.039450
# 2015-05-07 13:30:00      0.000000   11.625033                0.049417
# 2015-05-07 13:40:00      0.000000   10.197867                0.040475
# 2015-05-07 13:50:00      1.645000   10.796599                0.020867
# 2015-05-07 14:00:00   1573.285227   10.696624                0.048550
# 2015-05-07 14:10:00   1707.170530   10.464325                0.069217
# 2015-05-07 14:20:00   1819.672409   10.688631                0.070000
# 2015-05-07 14:30:00   2008.735167   11.121064                0.079450
# 2015-05-07 14:40:00   1384.687222    9.492211                0.070425
# 2015-05-07 14:50:00   1948.582323   10.978873                0.070000
# 2015-05-07 15:00:00   1238.072273    9.097403                0.070000
# ...

# %%
data_day1 = data.loc[pd.Timestamp('2015-05-07 12:10:00'):pd.Timestamp('2015-05-08 00:00:00')]

# %%
data_day1.shape
# Out:
# (66, 21)

# %%
data_day1['Active.Power'].plot()

# %%
data_day2 = data.loc[pd.Timestamp('2015-05-08 00:00:00'):pd.Timestamp('2015-05-09 00:00:00')]

# %%
data_day2['Active.Power'].plot()

# %%
data_day3 = data.loc[pd.Timestamp('2015-05-09 00:00:00'):pd.Timestamp('2015-05-10 00:00:00')]
data_day3['Active.Power'].plot()

# %%
data_day3
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-05-09 00:00:00    699.954705    7.333757                0.040000
# 2015-05-09 00:10:00    602.141724    7.117360                0.049367
# 2015-05-09 00:20:00    464.207904    6.215138                0.050000
# 2015-05-09 00:30:00    370.741918    5.712366                0.059392
# 2015-05-09 00:40:00    150.011488    4.611293                0.041183
# 2015-05-09 00:50:00     25.250833    3.440641                0.040000
# 2015-05-09 01:00:00      0.000000    2.507783                0.040000
# 2015-05-09 01:10:00      0.000000    3.354106                0.059000
# 2015-05-09 01:20:00      0.000000    4.273092                0.041117
# 2015-05-09 01:30:00    142.569375    5.271367                0.001867
# 2015-05-09 01:40:00    290.038125    5.739996                0.028650
# 2015-05-09 01:50:00    415.138611    6.285106                0.030000
# ...

# %%
data_day4 = data.loc[pd.Timestamp('2015-05-10 00:00:00'):pd.Timestamp('2015-05-11 00:00:00')]
data_day4['Active.Power'].plot()

# %%
data['Wind.Speed'].plot()

# %%
import seaborn as sns

# %%
sns.distplot(data['Wind.Speed'])
# Out:
# /Users/amit.panda03/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(data['Blade3.Pitch.Angle'])

# %%
data['Blade3.Pitch.Angle'].describe()
# Out:
# count    30682.000000
# mean         7.632782
# std         17.915639
# min        -79.879598
# 25%          1.207869
# 50%          1.710977
# 75%          2.606779
# max         97.130423
# Name: Blade3.Pitch.Angle, dtype: float64

# %%
data['Blade3.Pitch.Angle'].value_counts()
# Out:
# 79.519997    77
# 81.040001    57
# 78.220001    39
# 79.949997    37
# 80.220001    32
# 78.230003    32
# 78.040001    32
# 1.040000     30
# 80.849998    30
# 78.410004    30
# 81.589996    29
# 79.559998    29
# 78.610001    29
# 80.709999    28
# 0.960000     25
# 1.050000     24
# 78.870003    24
# 82.230003    22
# 81.129997    22
# 78.129997    22
# 78.919998    22
# 80.820000    21
# 78.010002    21
# 77.820000    21
# 80.180000    20
# 81.809998    19
# 80.660004    18
# 0.950000     18
# 80.139999    17
# 78.110001    17
#              ..
# 0.957635      1
# 1.482922      1
# 1.693688      1
# 3.349247      1
# 2.166755      1
# 1.039991      1
# 1.628916      1
# 1.069390      1
# 38.836589     1
# 1.610997      1
# 2.105880      1
# 2.573667      1
# 1.130169      1
# 2.230928      1
# 1.306755      1
# 2.735985      1
# 1.725375      1
# 1.314005      1
# 3.383024      1
# 1.022620      1
# 0.991358      1
# 1.728725      1
# 2.572411      1
# 1.523878      1
# ...

# %%
#Perform cross sectional analysis of 
#active power and wind speed, 
#wind speed and pitch data, 
#wind speed and temperature data.

# %%
data.head(1)
# Out:
#                      Active.Power  Wind.Speed  Tower.Acceleration.RMS  \
# DateTime
# 2015-05-07 12:10:00           0.0   10.304991                0.029475
#
#                      Gen.Speed  Hub.Speed  Ambient.Temp  Gearbox.Oil.Temp  \
# DateTime
# 2015-05-07 12:10:00        0.0        0.0          28.1         33.074312
#
#                      Hydraulic.Oil.Temp  Nacelle.Temp  PCU.Heatsink.Temp  \
# DateTime
# 2015-05-07 12:10:00           30.020161     27.798381          31.733492
#
#                             ...          PCU.Blade2.Motor.Temp  \
# DateTime                    ...
# 2015-05-07 12:10:00         ...                      69.054955
#
#                      PCU.Blade3.Motor.Temp    Timer.Yaw  Direction_x  \
# DateTime
# 2015-05-07 12:10:00              62.360009  3202.919722        3.698
#
#                      Yaw.Error  Air.Density  Blade.Rotor.Angle  \
# DateTime
# 2015-05-07 12:10:00  84.324204        1.134         120.400002
#
# ...

# %%
data_power_speed = data.iloc[:,0:2]

# %%
data_power_speed.head()
# Out:
#                      Active.Power  Wind.Speed
# DateTime
# 2015-05-07 12:10:00         0.000   10.304991
# 2015-05-07 13:10:00         0.000   12.114834
# 2015-05-07 13:30:00         0.000   11.625033
# 2015-05-07 13:40:00         0.000   10.197867
# 2015-05-07 13:50:00         1.645   10.796599

# %%
for col in data.columns:
    print(col , data[data[col] == 0].shape)
# Out:
# Active.Power (3259, 21)
# Wind.Speed (2, 21)
# Tower.Acceleration.RMS (2048, 21)
# Gen.Speed (22, 21)
# Hub.Speed (49, 21)
# Ambient.Temp (0, 21)
# Gearbox.Oil.Temp (0, 21)
# Hydraulic.Oil.Temp (0, 21)
# Nacelle.Temp (0, 21)
# PCU.Heatsink.Temp (2, 21)
# PCU.Blade1.Motor.Temp (2, 21)
# PCU.Blade2.Motor.Temp (2, 21)
# PCU.Blade3.Motor.Temp (2, 21)
# Timer.Yaw (0, 21)
# Direction_x (1, 21)
# Yaw.Error (2, 21)
# Air.Density (2, 21)
# Blade.Rotor.Angle (2, 21)
# Blade1.Pitch.Angle (2, 21)
# Blade2.Pitch.Angle (2, 21)
# Blade3.Pitch.Angle (2, 21)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
plt.plot(seasonal_decompose(data_active_power).trend)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-012613defbf9> in <module>
# ----> 1 plt.plot(seasonal_decompose(data_active_power).trend)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     125             freq = pfreq
#     126         else:
# --> 127             raise ValueError("You must specify a freq or x must be a "
#     128                              "pandas object with a timeseries index with "
#     129                              "a freq not set to None")
#
# ValueError: You must specify a freq or x must be a pandas object with a timeseries index with a freq not set to None

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d %H:%M:%S')

# %%
#ap = pd.read_csv('AirPassengers.csv', index_col= 'Travel date', date_parser = dateparse)
data = pd.read_excel('Data-Wind_turbine_diagnosis.xlsx', sheet_name='Data', index_col='DateTime', date_parser = dateparse)

# %%
data.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
data_active_power = data.iloc[:,0:1]

# %%
plt.plot(seasonal_decompose(data_active_power).seasonal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-917b60b5de8e> in <module>
# ----> 1 plt.plot(seasonal_decompose(data_active_power).seasonal)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     125             freq = pfreq
#     126         else:
# --> 127             raise ValueError("You must specify a freq or x must be a "
#     128                              "pandas object with a timeseries index with "
#     129                              "a freq not set to None")
#
# ValueError: You must specify a freq or x must be a pandas object with a timeseries index with a freq not set to None

# %%
data_active_power.index.dtype
# Out:
# dtype('<M8[ns]')
